# %% [markdown]
# **This is Exploratory Data Analysis for MonkeyPox Published by the Centers for Disease Control and Preventiton (29 Jul 2022)**

# %% [markdown]
# # New Section

# %%
# We first Import Libraries
import pandas as pd
import plotly.graph_objects as go

# %% [markdown]
# #### We will Load MonkeyPox extracted in CDC Website

# %%
## Mount your Google Drive to Collaboratory
from google.colab import drive
drive.mount('/content/gdrive')

# Loading the CSV file
df = pd.read_csv('gdrive/My Drive/MPX-Data.csv')
df
# Out:
# Mounted at /content/gdrive
#                  Country  Cases                                 Category  \
# 0                Andorra      4  Has not historically reported monkeypox
# 1              Argentina     31  Has not historically reported monkeypox
# 2              Australia     58  Has not historically reported monkeypox
# 3                Austria    160  Has not historically reported monkeypox
# 4                Bahamas      1  Has not historically reported monkeypox
# ..                   ...    ...                                      ...
# 83  United Arab Emirates     16  Has not historically reported monkeypox
# 84        United Kingdom   2859  Has not historically reported monkeypox
# 85         United States   7509  Has not historically reported monkeypox
# 86               Uruguay      2  Has not historically reported monkeypox
# 87             Venezuela      1  Has not historically reported monkeypox
#
#                                   AsOf
# ...

# %%
country_list = df["Country"].tolist()
#country_list
country_set = set(country_list)
#country_set
country_list = list(country_set)
#country_list
country_list.sort()
country_list

total_cases = df["Cases"].tolist()
total_cases
# Out:
# [4,
#  31,
#  58,
#  160,
#  1,
#  1,
#  482,
#  3,
#  1,
#  3,
#  1,
#  1474,
#  4,
#  7,
#  957,
#  8,
#  69,
#  20,
#  3,
#  12,
#  1,
#  28,
#  163,
#  114,
#  4,
#  6,
#  9,
#  22,
#  2423,
#  1,
#  2887,
#  30,
#  5,
#  39,
#  1,
#  1,
#  48,
#  11,
#  6,
#  97,
#  160,
#  545,
#  2,
#  2,
#  3,
#  6,
#  2,
#  3,
#  32,
#  17,
#  1,
#  91,
#  1,
#  1,
#  959,
#  1,
#  3,
#  133,
#  64,
#  1,
#  340,
#  1,
#  76,
#  710,
#  2,
#  2,
#  22,
#  1,
#  1,
#  5,
#  10,
#  15,
#  8,
#  37,
#  3,
#  1,
#  4942,
#  1,
#  111,
#  316,
#  2,
#  4,
#  1,
#  16,
#  2859,
#  7509,
#  2,
#  1]

# %%
new_data = pd.DataFrame(list(zip(country_list, total_cases)), columns = ['Country', 'Cases'])
new_data.head()
# Out:
#      Country  Cases
# 0    Andorra      4
# 1  Argentina     31
# 2  Australia     58
# 3    Austria    160
# 4    Bahamas      1

# %%
colors = ["#F9F9F5", "#FAFAE6", "#FCFCCB", "#FCFCAE",  "#FCF1AE", "#FCEA7D", "#FCD97D",
          "#FCCE7D", "#FCC07D", "#FEB562", "#F9A648",  "#F98E48", "#FD8739", "#FE7519",
          "#FE5E19", "#FA520A", "#FA2B0A", "#9B1803",  "#861604", "#651104", "#570303",]

# %%
fig = go.Figure(data=go.Choropleth(
    locationmode = "country names",
    locations = new_data['Country'],
    z = new_data['Cases'],
    text = new_data['Cases'],
    colorscale = colors,
    autocolorscale=False,
    reversescale=False,
    colorbar_title = 'Reported MonkeyPox Cases:: ',
))

fig.update_layout(
    title_text='Reported MonkeyPox Cases :: Hooli Developers (www.hooli.co.tz)',
    geo=dict(
        showcoastlines=True,
    ),
)

#fig.write_html('monkey.html', auto_open=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
